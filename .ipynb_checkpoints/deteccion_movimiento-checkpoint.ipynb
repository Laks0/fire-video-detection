# %% [markdown]
# #

# %%
from Movement_functions import *
from Color_functions import coincidencia, video_otsu_a, video_rgb
from skimage import io, measure
import matplotlib.pyplot as plt
plt.gray()

# %%
video_dir = "videos5fps/forest2.avi"

# %%
M_t = matriz_de_movimiento(video_dir)

# %%
F_t = video_otsu_a(video_dir)

# %%
V = video_rgb(video_dir)

# %%
C = [M_t[i]&F_t[i] for i in range(len(M_t))]

# %%
fig, axes = plt.subplots(3, 5, figsize=(45,15))

# Plotteo un par de ejemplos de la lista de M 
for i in range(30,35):
    axes[0][i-30].imshow(V[i])
    axes[1][i-30].imshow(C[i])
    axes[2][i-30].imshow(V[i]*C[i][...,None])

plt.show()

# %%
comps = componentes_que_crecen(np.array(C[:15]), tiempo_buffer=5, min_crecimiento=.4, min_area=10)

# %%
fig, axes = plt.subplots(3, 5, figsize=(45,15))

for i in range(5):
    axes[0][i].imshow(comps[5+i])
    axes[1][i].imshow(V[10+i])
    axes[2][i].imshow(comps[5+i][...,None] * V[15+i])
